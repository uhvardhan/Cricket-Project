# %%
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('dark_background')

# %%
# Load the data
drs_data = pd.read_excel("../data/drs_data.xlsx", header=0)
# Print the first 5 rows of the data
drs_data.head()
# Out:
#    Match Home Team Away Team  Innings Batting Team Fielding Team  Over  \
# 0      1       CSK       RCB        1          RCB           CSK    19
# 1      1       CSK       RCB        1          RCB           CSK    20
# 2      1       CSK       RCB        1          RCB           CSK    20
# 3      1       CSK       RCB        2          CSK           RCB    13
# 4      1       CSK       RCB        2          CSK           RCB    19
#
#   Review By      Umpire Umpire Abbreviation Decision Challenged  \
# 0       RCB  HAS Khalid                HASK                Wide
# 1       RCB   VK Sharma                 VKS                Wide
# 2       RCB   VK Sharma                 VKS                Wide
# 3       RCB   VK Sharma                 VKS              Wicket
# 4       RCB  HAS Khalid                HASK              Wicket
#
#   Original Decision DRS Decision      Batter             Bowler        Result  \
# 0        Not Called       Called  KD Karthik  Mustafizur Rahman    Successful
# 1        Not Called   Not Called  KD Karthik       TU Deshpande  Unsuccessful
# 2        Not Called   Not Called  KD Karthik       TU Deshpande  Unsuccessful
# 3           Not Out      Not Out      S Dube            C Green  Unsuccessful
# 4           Not Out      Not Out      S Dube          AS Joseph  Unsuccessful
#
#   Umpires Call
# 0           No
# 1           No
# 2           No
# 3           No
# 4           No

# %%
# Check if all the columns are of correct data type
drs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Match                51 non-null     int64
#  1   Home Team            51 non-null     object
#  2   Away Team            51 non-null     object
#  3   Innings              51 non-null     int64
#  4   Batting Team         51 non-null     object
#  5   Fielding Team        51 non-null     object
#  6   Over                 51 non-null     int64
#  7   Review By            51 non-null     object
#  8   Umpire               51 non-null     object
#  9   Umpire Abbreviation  51 non-null     object
#  10  Decision Challenged  51 non-null     object
#  11  Original Decision    51 non-null     object
#  12  DRS Decision         51 non-null     object
#  13  Batter               51 non-null     object
#  14  Bowler               51 non-null     object
#  15  Result               51 non-null     object
#  16  Umpires Call         51 non-null     object
# dtypes: int64(3), object(14)
# memory usage: 6.9+ KB

# %%
# Get the shape of the dataframe
drs_data.shape
# Out:
# (51, 17)

# %% [markdown]
# ### How many reviews in each innings?

# %% [markdown]
# ### How many reviews have been taken in each over?

# %%
f = plt.figure(figsize=(7,5))
ax = sns.countplot(data=drs_data, x="Over", color="green")

# %% [markdown]
# ### Wide reviews vs Wicket reviews vs Noball reviews

# %%
wide_reviews = drs_data[drs_data["Decision Challenged"]=="Wide"]
wicket_reviews = drs_data[drs_data["Decision Challenged"]=="Wicket"]
noball_reviews = drs_data[drs_data["Decision Challenged"]=="NoBall"]

# %%
print("Wides have been reviewed", wide_reviews.__len__(), "times")
print("Wickets have been reviewed", wicket_reviews.__len__(), "times")
print("No Balls have been reviewed", noball_reviews.__len__(), "times")
# Out:
# Wides have been reviewed 23 times
# Wickets have been reviewed 26 times
# No Balls have been reviewed 2 times

# %%
f = plt.figure(figsize=(7,5))
ax = f.add_subplot(1,1,1)
sns.histplot(data=drs_data, x="Decision Challenged", hue="Result", multiple="stack", stat="count", legend=True)
ax.set_title("What kind of decisions are being challenged?");

# %% [markdown]
# ### How well are umpires performing?

# %%
f = plt.figure(figsize=(10,7))
ax = f.add_subplot(1,1,1)
sns.histplot(data=drs_data, x="Umpire Abbreviation", hue="Result", multiple="stack", stat="count", legend=True)
ax.set_title("How well are the umpires performing when referred?");
ax.set_xlabel("Umpire")
# Out:
# Text(0.5, 0, 'Umpire')

# %% [markdown]
# ### Which teams have reviewed the most?

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(111)
sns.countplot(data=drs_data, x="Review By", hue="Result");

# %% [markdown]
# ### Who asked for a referral? Batting or Bowling?
