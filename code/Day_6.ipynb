# %%
import pandas as pd # type: ignore
import seaborn as sns # type: ignore
import matplotlib.pyplot as plt # type: ignore

plt.style.use('dark_background') # I love dark mode.

# %%
# Load the data
drs_data = pd.read_excel("../data/drs_data.xlsx", header=0)
# Print the total number of challenges in the dataset
print("Total number of challenges in the dataset: ", drs_data.shape[0])
# Out:
# Total number of challenges in the dataset:  197

# %%
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111)
# Create countplot
ax = sns.countplot(data=drs_data, x="Match", color="yellow")
ax.set_title("IPL 2024: Reviews in each match")
# ax.axis("equal")
ax.set_xlabel("Match number")
ax.set_ylabel("Number of reviews")
plt.tight_layout()
plt.savefig("../plots/reviews_in_each_match.png", bbox_inches='tight', dpi=720)
plt.show()
