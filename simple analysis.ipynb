# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
drs_data = pd.read_excel("drs_data.xlsx", header=0)

# %%
drs_data
# Out:
#     Match Home Team Away Team  Innings Batting Team Fielding Team  Over  \
# 0       1       CSK       RCB        1          RCB           CSK    19
# 1       1       CSK       RCB        1          RCB           CSK    20
# 2       1       CSK       RCB        1          RCB           CSK    20
# 3       1       CSK       RCB        2          CSK           RCB    13
# 4       1       CSK       RCB        2          CSK           RCB    19
# 5       2        DC      PBKS        1           DC          PBKS     8
# 6       2        DC      PBKS        1           DC          PBKS    14
# 7       2        DC      PBKS        1           DC          PBKS    19
# 8       2        DC      PBKS        2         PBKS            DC     7
# 9       3       KKR       SRH        1          KKR           SRH    16
# 10      3       KKR       SRH        2          SRH           KKR     2
# 11      3       KKR       SRM        2          SRH           KKR    13
# ...

# %%
drs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Match                38 non-null     int64
#  1   Home Team            38 non-null     object
#  2   Away Team            38 non-null     object
#  3   Innings              38 non-null     int64
#  4   Batting Team         38 non-null     object
#  5   Fielding Team        38 non-null     object
#  6   Over                 38 non-null     int64
#  7   Review By            38 non-null     object
#  8   Umpire               38 non-null     object
#  9   Decision Challenged  38 non-null     object
#  10  Batter               38 non-null     object
#  11  Result               38 non-null     object
#  12  Umpires Call         38 non-null     object
# dtypes: int64(3), object(10)
# memory usage: 4.0+ KB

# %%
sns.histplot(data=drs_data, x="Over", bins=20, binwidth=1, stat="count")
plt.xticks(range(0, 21))
plt.title("")
plt.show()
# Out:
# /Users/harshvardhanuppaluru/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
